# %% [markdown]
# <a href="https://colab.research.google.com/github/fadhilhamdi/Pembelajaran-Mesin_Muhammad-Fadhil-Hamdi_2211533018/blob/main/agglomerativeclustering_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler

# %%
# Membaca dataset dari file CSV
file_path = 'framingham.csv'  # Ganti dengan path ke file dataset Anda
data = pd.read_csv(file_path)

# %%
# Pastikan memilih kolom yang relevan untuk clustering
# Misalnya, jika dataset memiliki kolom 'feature1' dan 'feature2'
X = data[['currentSmoker', 'age']].values

# %%
# Opsional: Normalisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Membuat model Agglomerative Clustering
model = AgglomerativeClustering(n_clusters=3)
y_pred = model.fit_predict(X_scaled)

# %%
# Plot hasil clustering
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y_pred, cmap='rainbow')
plt.title("Agglomerative Clustering")
plt.xlabel('currentSmoker')
plt.ylabel('age')
plt.show()

# %%
# Plot Dendrogram
Z = linkage(X_scaled, 'ward')
plt.figure(figsize=(10, 7))
dendrogram(Z, truncate_mode='lastp', p=12, leaf_rotation=45., leaf_font_size=15., show_contracted=True)
plt.title("Dendrogram")
plt.xlabel("Data Point")
plt.ylabel("Distance")
plt.show()
